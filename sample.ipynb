# %%
from shape_detector import *
file_name = 'triangle.png'
create_triangle_image(file_name)
# Out:
# Triangle image saved as triangle.png

# %%
template_img_contour, templat_img = find_shape_contour(file_name)

# %%
imshow("triangle image", templat_img)

# %%
run_camera(template_img_contour)
